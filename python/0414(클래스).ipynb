# %% [markdown]
# 262, 생성자
#
# Stock 클래스의 객체가 생성될 때 종목명과 종목코드를 입력 받을 수 있도록 생성자를 정의해보세요.
# ```
# 삼성 = Stock("삼성전자", "005930")

# %%
class stock:
  def __init__(self, name, code):
    self.name = name
    self.code = code
삼성 = stock("삼성전자", "005930")

print(삼성.name)
print(삼성.code)
# Out:
# 삼성전자
# 005930

# %% [markdown]
# 263. 메서드
# 객체에 종목명을 입력할 수 있는 set_name 메서드를 추가해보세요.
# ```
# a = Stock(None, None)
# a.set_name("삼성전자")

# %%
from enum import NAMED_FLAGS
class stock:
  def __self__(self, name, code):
    self.name = name
    self.code = code

  def set_name(self, name):
    self.name = name

a = stock(None, None)
a.set_name("삼성전자")
print(a.name)
